# %%
import numpy as np
import pandas as pd

# %%
import import_yahoofin as yf

# %%
START_DT = "2010-01-01"
END_DT = "2020-05-05"

# %%
OUT_PATH = "../data/"

OUT_FILE1 = "quandl_ustbills.csv"
OUT_FILE2 = "yahoo_SP500.csv"
OUT_FILE3 = "yahoo_balsheet.csv"

# %%
IN_PATH = "../data/"
IN_FILE1 = "eod_ticker_sector.csv"

# %%
ticker_sector_df =  pd.read_csv(IN_PATH + IN_FILE1)
ticker_sector_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 490 entries, 0 to 489
# Data columns (total 2 columns):
# ticker         490 non-null object
# sector_code    490 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 7.7+ KB

# %%
ticker_sector_df.head()
# Out:
#   ticker  sector_code
# 0      A            0
# 1    AAL            3
# 2    AAP            8
# 3   AAPL            1
# 4   ABBV            0

# %%
ticker_lst = list(ticker_sector_df['ticker'].values)
ticker_lst[:5]
# Out:
# ['A', 'AAL', 'AAP', 'AAPL', 'ABBV']

# %%
bal = yf.iter_tickers(ticker_lst, 'balance-sheet', OUT_PATH + 'yahoo_fin/')

# %%
bal.to_csv(OUT_PATH + OUT_FILE3)

# %%
bal.head()
# Out:
#                    Capital Lease Obligations  Common Stock Equity  \
# Date       ticker
# 2019-06-30 MSFT                    6188000.0          102330000.0
# 2018-06-30 MSFT                    5568000.0           82718000.0
# 2017-06-30 MSFT                          NaN           72394000.0
# 2016-06-30 MSFT                          NaN           71997000.0
# 2019-09-30 AAPL                          NaN           90488000.0
# 2018-09-30 AAPL                          NaN          107147000.0
# 2017-09-30 AAPL                          NaN          134047000.0
# 2016-09-30 AAPL                          NaN          128249000.0
# 2019-12-31 GOOG                   12009000.0          201442000.0
# 2018-12-31 GOOG                      62000.0          177628000.0
# 2017-12-31 GOOG                      26000.0          152502000.0
# 2016-12-31 GOOG                          0.0          139036000.0
#
#                    Invested Capital    Net Debt  Net Tangible Assets  \
# ...

# %%
10*500/60
# Out:
# 83.33333333333333
